# %%
import tensorflow as tf
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
from tensorflow.keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt

# %%
img = image.load_img('/content/whithy.jfif', target_size=(224, 224))
plt.imshow(img)
plt.show()

# %%
def classify(img_path):
    img = image.load_img(img_path, target_size=(224, 224))
#     model = tf.keras.applications.resnet50.ResNet50()
    model = ResNet50(weights='imagenet', include_top=True) # this equals no weights parameter
    img_array = image.img_to_array(img)
    img_batch = np.expand_dims(img_array, axis=0)
    img_preprocessed = preprocess_input(img_batch)
    prediction = model.predict(img_preprocessed)
    return decode_predictions(prediction, top=5)[0]

# %%
img = image.load_img('/content/whithy.jfif', target_size=(224, 224))
plt.imshow(img)
plt.show()
classify('/content/whithy.jfif')
# Out:
# 1/1 [==============================] - 1s 1s/step
# [('n03445777', 'golf_ball', 0.21588428),
#  ('n04254120', 'soap_dispenser', 0.16877328),
#  ('n04399382', 'teddy', 0.14567576),
#  ('n04019541', 'puck', 0.02344326),
#  ('n02134084', 'ice_bear', 0.022120213)]

# %%
img = image.load_img('/content/dog.jfif', target_size=(224, 224))
plt.imshow(img)
plt.show()
classify('/content/dog.jfif')
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7e1d18c55fc0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 2s 2s/step
# [('n02091134', 'whippet', 0.51265806),
#  ('n02091032', 'Italian_greyhound', 0.24899113),
#  ('n02091831', 'Saluki', 0.09541451),
#  ('n02109047', 'Great_Dane', 0.034825686),
#  ('n02110341', 'dalmatian', 0.015106907)]

# %%
img = image.load_img('/content/푸들.png', target_size=(224, 224))
plt.imshow(img)
plt.show()
classify('/content/푸들.png')
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7e1d0a726a70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 1s/step
# [('n02971356', 'carton', 0.26841867),
#  ('n04399382', 'teddy', 0.2413943),
#  ('n03131574', 'crib', 0.16234012),
#  ('n02110063', 'malamute', 0.07061508),
#  ('n03482405', 'hamper', 0.046096794)]

# %%
img = image.load_img('/content/123.jfif', target_size=(224, 224))
plt.imshow(img)
plt.show()
classify('/content/123.jfif')
# Out:
# 1/1 [==============================] - 1s 1s/step
# [('n04482393', 'tricycle', 0.29343262),
#  ('n03599486', 'jinrikisha', 0.17723435),
#  ('n03792782', 'mountain_bike', 0.14391184),
#  ('n02835271', 'bicycle-built-for-two', 0.12748691),
#  ('n03980874', 'poncho', 0.0941553)]

# %%
img = image.load_img('/content/1234.jfif', target_size=(224, 224))
plt.imshow(img)
plt.show()
classify('/content/1234.jfif')
# Out:
# 1/1 [==============================] - 1s 1s/step
# [('n03599486', 'jinrikisha', 0.32550448),
#  ('n04482393', 'tricycle', 0.16103178),
#  ('n02769748', 'backpack', 0.14035667),
#  ('n03709823', 'mailbag', 0.09829136),
#  ('n02797295', 'barrow', 0.0824338)]

# %%
img = image.load_img('/content/author_fleck.webp', target_size=(224, 224))
plt.imshow(img)
plt.show()
classify('/content/author_fleck.webp')
# Out:
# 1/1 [==============================] - 1s 1s/step
# [('n02865351', 'bolo_tie', 0.27400962),
#  ('n04479046', 'trench_coat', 0.12602608),
#  ('n04591157', 'Windsor_tie', 0.07204439),
#  ('n04350905', 'suit', 0.052419208),
#  ('n03763968', 'military_uniform', 0.025180267)]

# %%
# 모델 크기 확인
model = ResNet50(weights='imagenet', include_top=True) # this equals no weights parameter
model_size = model.count_params()
print(f"ResNet50 모델의 파라미터 수: {model_size}")
# Out:
# ResNet50 모델의 파라미터 수: 25636712
